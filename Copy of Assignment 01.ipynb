# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
num=int(input("How many number you want to input "))
i=1
lst=[]
while i <= num:
    item=input()
    lst.append(int(item))
    i+=1
even =list(filter(lambda lst: lst%2==0,lst))
print(even)
# Out:
# How many number you want to input 2
# 1
# 2
# [2]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("Input two integers")
a=int(input("1st Integer "))
b=int(input("2nd Integer "))
try:
    div=a/b
    print(f"Answer:{div}")
except ZeroDivisionError:
    print("Division by zero")
# Out:
# Input two integers
# 1st Integer 10
# 2nd Integer 0
# Division by zero

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Shape:
    def area(self):
        return 0
class Rectangle(Shape):
    def __init__(self, w, h):
        self.w = w
        self.h = h
    def area(self):
        return self.w * self.h

class Circle(Shape):
    def __init__(self, r):
        self.r = r
    def area(self):
        p = 3.1416
        return p * self.r * self.r
data = input().split()
shape_type = data[0]
if shape_type == "Rectangle":
    w=float(data[1])
    h=float(data[2])
    shape = Rectangle(w, h)
elif shape_type == "Circle":
    r = float(data[1])
    shape = Circle(r)
else:
    shape = Shape()
print(f"Area: {shape.area():.2f}")
# Out:
# Rectangle 5 10
# Area: 50.00

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
sentance=input()
word=sentance.split()
long=word[0]
for i in word:
    if len(i)>len(long):
        long=i
print(long)
# Out:
# python programming is enjoyable
# programming

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
num =int(input())
temp =num
sum_fact =0

def factorial(n):
    result =1
    for i in range(1, n+1):
        result =result * i
    return result

while temp>0:
    z =temp%10
    sum_fact= sum_fact+factorial(z)
    temp = temp // 10

if sum_fact==num:
    print("Strong Number")
else:
    print("Not strong Number")
# Out:
# 145
# Strong Number
